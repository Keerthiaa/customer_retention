# %% [markdown]
# # customer_retention

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("customer_retention_dataset.xlsx" , sheet_name=None)
#importing Dataset.

# %%
df.keys()
# Out:
# dict_keys(['datasheet', 'codedsheet'])

# %%
DF =  df['datasheet'] 
DF1 = df['codedsheet']

# %%
DF.shape
# Out:
# (269, 71)

# %% [markdown]
# since the data is large, it has been split below

# %%
data = DF.iloc[:,:47]
data_re = DF.iloc[:,47:]
data1 = DF1.iloc[:,:47]
data_re1 = DF1.iloc[:,47:]

# %%
data_re
# Out:
#     From the following, tick any (or all) of the online retailers you have shopped from;                                                                             \
# 0                                 Amazon.in, Paytm.com
# 1    Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 2                     Amazon.in, Paytm.com, Myntra.com
# 3    Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 4    Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# ..                                                 ...
# 264                                          Amazon.in
# 265                            Amazon.in, Flipkart.com
# 266              Amazon.in, Flipkart.com, Snapdeal.com
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#                     Easy to use website or application  \
# 0                                            Paytm.com
# 1    Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# ...

# %%
data_re1
# Out:
#     From the following, tick any (or all) of the online retailers you have shopped from;                                                                             \
# 0                                 Amazon.in, Paytm.com
# 1    Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 2                     Amazon.in, Paytm.com, Myntra.com
# 3    Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 4    Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# ..                                                 ...
# 264                                          Amazon.in
# 265                            Amazon.in, Flipkart.com
# 266              Amazon.in, Flipkart.com, Snapdeal.com
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#                     Easy to use website or application  \
# 0                                            Paytm.com
# 1    Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# ...

# %%
data_re.columns = [x.upper() for x in ['From_the_following', 'Easy','Visual_appealing', 'variety','description','Fast_loading',
                                     'Reliability','Quickness','payment_options', 'Speedy_order_delivery ','Privacy','Security',
                                     'Perceived','Presence','Login_Time','Display_Time','price','page_loading_time',
                                     'mode_of_payment','Longer_delivery period', 'design','Frequent_disruption','efficient',
                                     'Recommendation']]

data_re1.columns = [x.upper() for x in ['From_the_following', 'Easy','Visual_appealing', 'variety','description','Fast_loading',
                                     'Reliability','Quickness','payment_options', 'Speedy_order_delivery ','Privacy','Security',
                                     'Perceived','Presence','Login_Time','Display_Time','price','page_loading_time',
                                     'mode_of_payment','Longer_delivery period', 'design','Frequent_disruption','efficient',
                                     'Recommendation']]

# %%
col = ['Gender','Age','City','Pin_Code','Vintage','No.of_purchase/year','Usage_of internet','Deviced_used','Screen_size_mobile_device','OS',
'Browser','Channel_access','how_do you_reach_onlinestore','Time_taken','Payment_option','Abandon','Reason_abandon','content_ease','product_comparison',
'information','seller_information','Ease_navigation', 'Loading_speed','UX','Payment_methods','transaction_time','Empathy','privacy','Responsiveness',
'benefit_and_discounts','Enjoyment','flexible','Return_replacement','Benefit','satisfaction_customers','User_derive_satisfaction','Net Benefit',
'trust','several_category','product_information','Monetary_savings','Patronizing','Adventure','social_status','gratification','fulfilment','value_for_money_spent']

# %%
data.columns = [x.upper() for x in col]

data1.columns = [x.upper() for x in col]

# %% [markdown]
# exploratory data analysis

# %% [markdown]
# finding if their is any null data

# %%
data.isna().sum()
# Out:
# GENDER                          0
# AGE                             0
# CITY                            0
# PIN_CODE                        0
# VINTAGE                         0
# NO.OF_PURCHASE/YEAR             0
# USAGE_OF INTERNET               0
# DEVICED_USED                    0
# SCREEN_SIZE_MOBILE_DEVICE       0
# OS                              0
# BROWSER                         0
# CHANNEL_ACCESS                  0
# HOW_DO YOU_REACH_ONLINESTORE    0
# TIME_TAKEN                      0
# PAYMENT_OPTION                  0
# ABANDON                         0
# REASON_ABANDON                  0
# CONTENT_EASE                    0
# PRODUCT_COMPARISON              0
# INFORMATION                     0
# SELLER_INFORMATION              0
# EASE_NAVIGATION                 0
# LOADING_SPEED                   0
# UX                              0
# PAYMENT_METHODS                 0
# TRANSACTION_TIME                0
# EMPATHY                         0
# ...

# %%
data_re.isna().sum()
# Out:
# FROM_THE_FOLLOWING        0
# EASY                      0
# VISUAL_APPEALING          0
# VARIETY                   0
# DESCRIPTION               0
# FAST_LOADING              0
# RELIABILITY               0
# QUICKNESS                 0
# PAYMENT_OPTIONS           0
# SPEEDY_ORDER_DELIVERY     0
# PRIVACY                   0
# SECURITY                  0
# PERCEIVED                 0
# PRESENCE                  0
# LOGIN_TIME                0
# DISPLAY_TIME              0
# PRICE                     0
# PAGE_LOADING_TIME         0
# MODE_OF_PAYMENT           0
# LONGER_DELIVERY PERIOD    0
# DESIGN                    0
# FREQUENT_DISRUPTION       0
# EFFICIENT                 0
# RECOMMENDATION            0
# dtype: int64

# %% [markdown]
# their is no null data in the dataset

# %% [markdown]
# understanding the columns

# %%
data1.shape
# Out:
# (269, 47)

# %%
data_re1.shape
# Out:
# (269, 24)

# %%
data.shape
# Out:
# (269, 47)

# %%
data_re.shape
# Out:
# (269, 24)

# %%
data.dtypes
# Out:
# GENDER                          object
# AGE                             object
# CITY                            object
# PIN_CODE                         int64
# VINTAGE                         object
# NO.OF_PURCHASE/YEAR             object
# USAGE_OF INTERNET               object
# DEVICED_USED                    object
# SCREEN_SIZE_MOBILE_DEVICE       object
# OS                              object
# BROWSER                         object
# CHANNEL_ACCESS                  object
# HOW_DO YOU_REACH_ONLINESTORE    object
# TIME_TAKEN                      object
# PAYMENT_OPTION                  object
# ABANDON                         object
# REASON_ABANDON                  object
# CONTENT_EASE                    object
# PRODUCT_COMPARISON              object
# INFORMATION                     object
# SELLER_INFORMATION              object
# EASE_NAVIGATION                 object
# LOADING_SPEED                   object
# UX                              object
# ...

# %%
data_re.dtypes
# Out:
# FROM_THE_FOLLOWING        object
# EASY                      object
# VISUAL_APPEALING          object
# VARIETY                   object
# DESCRIPTION               object
# FAST_LOADING              object
# RELIABILITY               object
# QUICKNESS                 object
# PAYMENT_OPTIONS           object
# SPEEDY_ORDER_DELIVERY     object
# PRIVACY                   object
# SECURITY                  object
# PERCEIVED                 object
# PRESENCE                  object
# LOGIN_TIME                object
# DISPLAY_TIME              object
# PRICE                     object
# PAGE_LOADING_TIME         object
# MODE_OF_PAYMENT           object
# LONGER_DELIVERY PERIOD    object
# DESIGN                    object
# FREQUENT_DISRUPTION       object
# EFFICIENT                 object
# RECOMMENDATION            object
# dtype: object

# %% [markdown]
# univariate analysis

# %% [markdown]
# for better analysis,we have divided the data into different groups based
# customer details(during sales)
# customer's accesability(during sales)
# customer success details(after sales reviews)
# customer gratification(attitude of customers after sales)
# value column(target)

# %%
data_Customer_details_columns = data[['GENDER', 'AGE', 'CITY', 'PIN_CODE', 'VINTAGE', 'NO.OF_PURCHASE/YEAR',
       'USAGE_OF INTERNET', 'DEVICED_USED', 'SCREEN_SIZE_MOBILE_DEVICE', 'OS',
       'BROWSER', 'CHANNEL_ACCESS']]

data_Customer_details_columns1 = data1[['GENDER', 'AGE', 'CITY', 'PIN_CODE', 'VINTAGE', 'NO.OF_PURCHASE/YEAR',
       'USAGE_OF INTERNET', 'DEVICED_USED', 'SCREEN_SIZE_MOBILE_DEVICE', 'OS',
       'BROWSER', 'CHANNEL_ACCESS']]

data_accesability_columns = data[['HOW_DO YOU_REACH_ONLINESTORE',
       'TIME_TAKEN', 'PAYMENT_OPTION', 'ABANDON', 'REASON_ABANDON',
       'CONTENT_EASE', 'PRODUCT_COMPARISON', 'INFORMATION',
       'SELLER_INFORMATION', 'EASE_NAVIGATION', 'LOADING_SPEED', 'UX',
       'PAYMENT_METHODS', 'TRANSACTION_TIME']]

data_accesability_columns1 = data1[['HOW_DO YOU_REACH_ONLINESTORE',
       'TIME_TAKEN', 'PAYMENT_OPTION', 'ABANDON', 'REASON_ABANDON',
       'CONTENT_EASE', 'PRODUCT_COMPARISON', 'INFORMATION',
       'SELLER_INFORMATION', 'EASE_NAVIGATION', 'LOADING_SPEED', 'UX',
       'PAYMENT_METHODS', 'TRANSACTION_TIME']]

data_Customer_Success_details_columns = data[['EMPATHY', 'PRIVACY',
       'RESPONSIVENESS', 'BENEFIT_AND_DISCOUNTS', 'ENJOYMENT', 'FLEXIBLE',
       'RETURN_REPLACEMENT', 'BENEFIT', 'SATISFACTION_CUSTOMERS',
       'USER_DERIVE_SATISFACTION', 'NET BENEFIT', 'TRUST', 'SEVCustomer_detailsERAL_CATEGORY',
       'PRODUCT_INFORMATION',]]

data_Customer_Success_details_columns1 = data1[['EMPATHY', 'PRIVACY',
       'RESPONSIVENESS', 'BENEFIT_AND_DISCOUNTS', 'ENJOYMENT', 'FLEXIBLE',
       'RETURN_REPLACEMENT', 'BENEFIT', 'SATISFACTION_CUSTOMERS',
       'USER_DERIVE_SATISFACTION', 'NET BENEFIT', 'TRUST', 'SEVERAL_CATEGORY',
       'PRODUCT_INFORMATION',]]

data_Customer_Gratifications_columns = data[['MONETARY_SAVINGS', 'PATRONIZING', 'ADVENTURE',
       'SOCIAL_STATUS', 'GRATIFICATION', 'FULFILMENT']]

data_Customer_Gratifications_columns1 = data1[['MONETARY_SAVINGS', 'PATRONIZING', 'ADVENTURE',
       'SOCIAL_STATUS', 'GRATIFICATION', 'FULFILMENT']]

data_value_column = data['VALUE_FOR_MONEY_SPENT']

data_value_column1 = data1['VALUE_FOR_MONEY_SPENT']

# %%
for column in data.columns:
    if data[column].dtypes==object:
        print(str(column)+':'+str(data[column].unique()))
        print('..........................................')
        print('\n')
# Out:
# GENDER:['Male' 'Female']
# ..........................................
#
#
# AGE:['31-40 years' '21-30 years' '41-50 yaers' 'Less than 20 years'
#  '51 years and above']
# ..........................................
#
#
# CITY:['Delhi' 'Greater Noida' 'Karnal ' 'Bangalore ' 'Noida' 'Solan'
#  'Moradabad' 'Gurgaon ' 'Merrut' 'Ghaziabad' 'Bulandshahr']
# ..........................................
#
#
# VINTAGE:['Above 4 years' '3-4 years' '2-3 years' 'Less than 1 year' '1-2 years']
# ..........................................
#
#
# NO.OF_PURCHASE/YEAR:['31-40 times' '41 times and above' 'Less than 10 times' '11-20 times'
#  '21-30 times' '42 times and above']
# ..........................................
#
#
# USAGE_OF INTERNET:['Dial-up' 'Wi-Fi' 'Mobile Internet' 'Mobile internet']
# ..........................................
#
#
# DEVICED_USED:['Desktop' 'Smartphone' 'Tablet' 'Laptop']
# ..........................................
#
#
# ...

# %%
for column in data1.columns:
    if data[column].dtypes==object:
        print(str(column)+':'+str(data1[column].unique()))
        print('..........................................')
        print('\n')
# Out:
# GENDER:[0 1]
# ..........................................
#
#
# AGE:[3 2 4 1 5]
# ..........................................
#
#
# CITY:['Delhi' 'Greater Noida' 'Karnal ' 'Bangalore ' 'Noida' 'Solan'
#  'Moradabad' 'Gurgaon ' 'Merrut' 'Ghaziabad' 'Bulandshahr']
# ..........................................
#
#
# VINTAGE:[5 4 3 1 2]
# ..........................................
#
#
# NO.OF_PURCHASE/YEAR:[4 5 1 2 3]
# ..........................................
#
#
# USAGE_OF INTERNET:[4 2 3 5]
# ..........................................
#
#
# DEVICED_USED:[3 1 4 2]
# ..........................................
#
#
# SCREEN_SIZE_MOBILE_DEVICE:[5 2 4]
# ..........................................
#
#
# OS:[1 3 2]
# ..........................................
#
#
# BROWSER:[1 2 4 3]
# ..........................................
#
#
# CHANNEL_ACCESS:[1 3 4]
# ..........................................
#
#
# HOW_DO YOU_REACH_ONLINESTORE:[1 4 3 2]
# ..........................................
#
#
# ...

# %%
plt.subplots(figsize=(5,5))
sns.countplot(x='GENDER',data=data)
plt.title("GENDER count analysis")
plt.xlabel('GENDER')
plt.ylabel('count')
plt.xticks(rotation=100)

plt.show()

# %%
plt.subplots(figsize=(5,5))
sns.countplot(x='AGE',data=data)
plt.title("AGE count analysis")
plt.xlabel('AGE')
plt.ylabel('count')
plt.xticks(rotation=100)

plt.show()

# %%
plt.subplots(figsize=(5,5))
sns.countplot(x='CITY',data=data)
plt.title("CITY count analysis")
plt.xlabel('CITY')
plt.ylabel('count')
plt.xticks(rotation=100)

plt.show()

# %%
plt.subplots(figsize=(5,5))
sns.countplot(x='VINTAGE',data=data)
plt.title("VINTAGE count analysis")
plt.xlabel('VINTAGE')
plt.ylabel('count')
plt.xticks(rotation=100)

plt.show()

# %%
plt.subplots(figsize=(5,5))
sns.countplot(x='NO.OF_PURCHASE/YEAR',data=data)
plt.title("NO.OF_PURCHASE/YEAR count analysis")
plt.xlabel('NO.OF_PURCHASE/YEAR')
plt.ylabel('count')
plt.xticks(rotation=100)

plt.show()

# %%
plt.subplots(figsize=(5,5))
sns.countplot(x='DEVICED_USED',data=data)
plt.title("DEVICED_USED count analysis")
plt.xlabel('DEVICED_USED')
plt.ylabel('count')
plt.xticks(rotation=100)

plt.show()

# %%
plt.subplots(figsize=(5,5))
sns.countplot(x='USAGE_OF INTERNET',data=data)
plt.title("USAGE_OF INTERNET count analysis")
plt.xlabel('USAGE_OF INTERNET')
plt.ylabel('count')
plt.xticks(rotation=100)

plt.show()

# %%
plt.subplots(figsize=(5,5))
sns.countplot(x='SCREEN_SIZE_MOBILE_DEVICE',data=data)
plt.title("q2SCREEN_SIZE_MOBILE_DEVICEq count analysis")
plt.xlabel('SCREEN_SIZE_MOBILE_DEVICE')
plt.ylabel('count')
plt.xticks(rotation=100)

plt.show()

# %%
plt.subplots(figsize=(5,5))
sns.countplot(x='OS',data=data)
plt.title("OS count analysis")
plt.xlabel('OS')
plt.ylabel('count')
plt.xticks(rotation=100)

plt.show()

# %%
plt.subplots(figsize=(5,5))
sns.countplot(x='BROWSER',data=data)
plt.title("BROWSER count analysis")
plt.xlabel('BROWSER')
plt.ylabel('count')
plt.xticks(rotation=100)

plt.show()

# %%
plt.subplots(figsize=(5,5))
sns.countplot(x='CHANNEL_ACCESS',data=data)
plt.title("CHANNEL_ACCESS count analysis")
plt.xlabel('CHANNEL_ACCESS')
plt.ylabel('count')
plt.xticks(rotation=100)

plt.show()

# %% [markdown]
# since customers details have high impact on on sales, after sales anlaysis we have choose to make for each column detailed analysis unlike other sets
# from analysis we found
# no of females are more in our sample and also found age range between 31 years to 50 years are involved in purchasing maximum
# delhi, great noida, noida, bangalore are the cities with highest frequency of sales respectively
# 2-3 years and 4 years above is most expected vintage
# frequency of purchases made in a year depicts that less than 10 times & 31-40 times is most frequent purchase which depicts the type of products are prefered on e commerce
# most of them use smartphones(windows - OS) and laptops to browse and make orders for this purpose internet is mostly from mobile data and wifi,
# GOOGLE CHROME search engine is the prefered access

# %%
plt.subplots(figsize=(5,5))
sns.countplot(x='REASON_ABANDON',data=data)
plt.title("REASON_ABANDON count analysis")
plt.xlabel('REASON_ABANDON')
plt.ylabel('count')
plt.xticks(rotation=100)

plt.show()

# %%
collist = data_accesability_columns.columns.values

plt.figure(figsize=(20,10))

for i in range(0,len(collist)):
    plt.subplot(5,3,i+1)
    data[collist[i]].hist()
    plt.title(f"{[collist[i]]}")
    plt.ylabel('Count')
    plt.tight_layout()

# %% [markdown]
# data accesability depicts a set of information about how convenient it is for customers to reach the products
# we found search engine and application through ccustomers are able to reach the ecommerce stores eaasily and most of the customers taken more than 15minutes to browse the items (categorical bifercation & more filters preferred)
# while at the time of purchases it was found sometimes customers had left abandon due to better alternative offers
# customers are of opinion that content ease, product comparision, information, seller information, ease navigation,ux, loading speed are appreciable parts of the of shopping site
# finally payment method are mostly cards or cash on delivery and payment options and transaction time are also appreciable

# %%
collist = data_Customer_Success_details_columns.columns.values

plt.figure(figsize=(20,10))

for i in range(0,len(collist)):
    plt.subplot(5,3,i+1)
    data[collist[i]].hist()
    plt.title(f"{[collist[i]]}")
    plt.ylabel('Count')
    plt.tight_layout()

# %% [markdown]
# the most important set of information which is going to decide the customers value for money is customers sales details
# and found all the columns are been strongly agreed by customers which means customers are satisfied with the aservices and can give more importance towards
# benefits&discounts
# enjoyment
# trust &
# category

# %%
collist = data_Customer_Gratifications_columns.columns.values

plt.figure(figsize=(20,10))

for i in range(0,len(collist)):
    plt.subplot(5,3,i+1)
    data[collist[i]].hist()
    plt.title(f"{[collist[i]]}")
    plt.ylabel('Count')
    plt.tight_layout()

# %% [markdown]
# this set depicts the customers fulfillment and satisfaction in purchasing products through ecommerce
# social status
# gratification
# fulfillment are the categories the ecommerce platforms have to improve

# %%
plt.subplots(figsize=(5,5))
sns.countplot(x='VALUE_FOR_MONEY_SPENT',data=data)
plt.title("VALUE_FOR_MONEY_SPENT count analysis")
plt.xlabel('VALUE_FOR_MONEY_SPENT')
plt.ylabel('count')
plt.xticks(rotation=100)

plt.show()

# %% [markdown]
# Most of the Customers agrees with the hedonic value that the E_commerse gives the customer and nearly half of the population decalers they stongly agree.

# %%
multivariate analysis

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data_Customer_details_columns1.corr(), annot = True, cmap= "coolwarm")
plt.show()

# %% [markdown]
# we can find their is correlation  existing between browser and channel acceess by 61%
# device used and screen size of device by 60%
# browser and operating system by 41%
#
# no or high negative correlation is found between operating system and screen size of mobile
# operating system and device used
# browser and device used

# %%
cor = data_Customer_details_columns1.join(data_value_column1)
plt.figure(figsize=(8,6))
cor.corr()['VALUE_FOR_MONEY_SPENT'].sort_values(ascending=False).drop(['VALUE_FOR_MONEY_SPENT']).plot(kind='bar',grid=True)
plt.xticks(rotation=90)
plt.title("correlation with target variables")

plt.show()

# %% [markdown]
# value for money and customer details correlation has shown
#  gender, no of purchases/year,os and vintage are highly related to value of money

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data_accesability_columns1.corr(), annot = True, cmap= "coolwarm")
plt.show()

# %%
high correlation between
content ease and seller informatiomn 90%
ux and payment method 90%
product comparision and ease navigation by 86%

# %%
cor = data_accesability_columns1.join(data_value_column1)
plt.figure(figsize=(8,6))
cor.corr()['VALUE_FOR_MONEY_SPENT'].sort_values(ascending=False).drop(['VALUE_FOR_MONEY_SPENT']).plot(kind='bar',grid=True)
plt.xticks(rotation=90)
plt.title("correlation with target variables")

plt.show()

# %%
cor = data_Customer_Success_details_columns1.join(data_value_column1)
plt.figure(figsize=(8,6))
cor.corr()['VALUE_FOR_MONEY_SPENT'].sort_values(ascending=False).drop(['VALUE_FOR_MONEY_SPENT']).plot(kind='bar',grid=True)
plt.xticks(rotation=90)
plt.title("correlation with target variables")

plt.show()

# %%
cor = data_Customer_Gratifications_columns1.join(data_value_column1)
plt.figure(figsize=(8,6))
cor.corr()['VALUE_FOR_MONEY_SPENT'].sort_values(ascending=False).drop(['VALUE_FOR_MONEY_SPENT']).plot(kind='bar',grid=True)
plt.xticks(rotation=90)
plt.title("correlation with target variables")

plt.show()

# %%
plt.figure(figsize=(15,5))
data1.corr()['VALUE_FOR_MONEY_SPENT'].sort_values(ascending=False).drop(['VALUE_FOR_MONEY_SPENT']).plot.bar()
plt.xlabel("Feature", fontsize= 14)
plt.ylabel("correlation with Target column", fontsize = 18)
plt.title("Correlation of all Features with the Target column", fontsize=25)
plt.show()
